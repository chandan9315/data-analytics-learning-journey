# %%
import numpy as np
v=np.array([2,5,4,9,3,8])
v
# Out:
# array([2, 5, 4, 9, 3, 8])

# %%
np.var(v)
# Out:
# np.float64(6.472222222222222)

# %%
np.std(v)
# Out:
# np.float64(2.544056253745625)

# %%
m=np.mean(v)
m
# Out:
# np.float64(5.166666666666667)

# %%
y=m-v
y
# Out:
# array([ 3.16666667,  0.16666667,  1.16666667, -3.83333333,  2.16666667,
#        -2.83333333])

# %%
b=y**2
b
# Out:
# array([10.02777778,  0.02777778,  1.36111111, 14.69444444,  4.69444444,
#         8.02777778])

# %%
u=np.sum(b)/len(v)
u
# Out:
# np.float64(6.472222222222222)

# %%
c=np.sqrt(u)
c
# Out:
# np.float64(2.544056253745625)

# %%
# x=np.array([5,10,5,11,12,4,3,2,7,1])
# y=np.array([1,6,2,8,5,1,4,6,5,2

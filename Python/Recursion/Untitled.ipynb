# %%
# Recursion:
# Recursion in Python is a programming technique where a function calls itself to solve a problem by breaking it down into smaller,
# simpler subproblems. This process continues until a basic, solvable condition is m

# %%
def fact(x):
    if(x==1):
        return 1
    else:
        return x*fact(x-1)

t=fact(5)
print(t)
# Out:
# 120

# %%
def sum(x):
    if (x==1):
        return 1
    else:
        return x + sum(x-1)

t=sum(10)
print("sum of 1 to 10 : ",t)
# Out:
# sum of 1 to 10 :  55

# %%
def sum_n(x):
    if (x==11):
        return 0
    else:
        return x + sum_n(x+1)

t=sum_n(10)
print("sum of 1 to 10 : ",t)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[7], line 7
#       4     else:
#       5         return x + sum_n(x-1)
# ----> 7 t=sum_n(10)
#       8 print("sum of 1 to 10 : ",t)
#
# Cell In[7], line 5, in sum_n(x)
#       3     return 0
#       4 else:
# ----> 5     return x + sum_n(x-1)
#
# Cell In[7], line 5, in sum_n(x)
#       3     return 0
#       4 else:
# ----> 5     return x + sum_n(x-1)
#
#     [... skipping similar frames: sum_n at line 5 (2974 times)]
#
# Cell In[7], line 5, in sum_n(x)
#       3     return 0
#       4 else:
# ----> 5     return x + sum_n(x-1)
#
# RecursionError: maximum recursion depth exceeded

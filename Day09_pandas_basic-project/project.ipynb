# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\asus\Desktop\Datasets\crime_dataset_india.csv")
df.head()
# Out:
#    Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0              1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1              2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2              3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3              4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4              5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
#
#         City  Crime Code Crime Description  Victim Age Victim Gender  \
# 0  Ahmedabad         576    IDENTITY THEFT          16             M
# 1    Chennai         128          HOMICIDE          37             M
# 2   Ludhiana         271        KIDNAPPING          48             F
# 3       Pune         170          BURGLARY          49             F
# 4       Pune         421         VANDALISM          30             F
#
#     Weapon Used   Crime Domain  Police Deployed Case Closed  Date Case Closed
# ...

# %%
df.shape
# Out:
# (40160, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40160 entries, 0 to 40159
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Report Number       40160 non-null  int64
#  1   Date Reported       40160 non-null  object
#  2   Date of Occurrence  40160 non-null  object
#  3   Time of Occurrence  40160 non-null  object
#  4   City                40160 non-null  object
#  5   Crime Code          40160 non-null  int64
#  6   Crime Description   40160 non-null  object
#  7   Victim Age          40160 non-null  int64
#  8   Victim Gender       40160 non-null  object
#  9   Weapon Used         34370 non-null  object
#  10  Crime Domain        40160 non-null  object
#  11  Police Deployed     40160 non-null  int64
#  12  Case Closed         40160 non-null  object
#  13  Date Case Closed    20062 non-null  object
# dtypes: int64(4), object(10)
# memory usage: 4.3+ MB

# %%
df.isnull().sum()
# Out:
# Report Number             0
# Date Reported             0
# Date of Occurrence        0
# Time of Occurrence        0
# City                      0
# Crime Code                0
# Crime Description         0
# Victim Age                0
# Victim Gender             0
# Weapon Used            5790
# Crime Domain              0
# Police Deployed           0
# Case Closed               0
# Date Case Closed      20098
# dtype: int64

# %%
import numpy as np

# %%
k=np.array([20000,30000,50000,1500000,70000,90000])
k
# Out:
# array([  20000,   30000,   50000, 1500000,   70000,   90000])

# %%
plt.boxplot(k)
plt.show()

# %%
s=np.quantile(k,0.25)
s
# Out:
# np.float64(35000.0)

# %%
s2=np.quantile(k,0.50)
s2
# Out:
# np.float64(60000.0)

# %%
s3=np.quantile(k,0.75)
s3
# Out:
# np.float64(85000.0)

# %%
h=s3-s
h
# Out:
# np.float64(50000.0)

# %%
upper=s3+(1.5*h)
upper
# Out:
# np.float64(160000.0)

# %%
lower=s-(1.5*h)
lower
# Out:
# np.float64(-40000.0)

# %%
k
# Out:
# array([  20000,   30000,   50000, 1500000,   70000,   90000])

# %%
v=[]
for i in k:
    if(i>upper or i<lower):
        v.append(i)
v
# Out:
# [np.int64(1500000)]

# %%
v2=[]
for i in k:
    if(i>lower and i<upper):
        v2.append(i)
print(v2)
# Out:
# [np.int64(20000), np.int64(30000), np.int64(50000), np.int64(70000), np.int64(90000)]

# %%
plt.boxplot(v2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a980f8c190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a980f8c410>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a980f8c050>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a980f8c690>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a980f8c7d0>],
#  'means': []}

# %%
df=pd.read_excel(r"C:\Users\asus\Desktop\Datasets\Raw data .xlsx")
df.head()
# Out:
#    Id     Name Lastname  Salary Department  Mobile no.
# 0   1    Anshu   Rajput   90000      Sales  8595787610
# 1   2   Manish    Kumar   62000  Marketing  8595787611
# 2   3    Aadil     Khan   70000    Finance  8595787612
# 3   4  Chandan   Thakur   80000         IT  8595787613
# 4   5     Aman    Anand   20000      Sales  8595787614

# %%
df['Taxsalary']=df['Salary']*0.1

# %%
df
# Out:
#     Id      Name  Lastname  Salary Department  Mobile no.  Taxsalary
# 0    1     Anshu    Rajput   90000      Sales  8595787610     9000.0
# 1    2    Manish     Kumar   62000  Marketing  8595787611     6200.0
# 2    3     Aadil      Khan   70000    Finance  8595787612     7000.0
# 3    4   Chandan    Thakur   80000         IT  8595787613     8000.0
# 4    5      Aman     Anand   20000      Sales  8595787614     2000.0
# 5    6     Badal     Singh   65000  Marketing  8595787615     6500.0
# 6    7      Anil     Yadav   55000    Finance  8595787616     5500.0
# 7    8     Akash     Verma   75000         IT  8595787617     7500.0
# 8    9      Yash  Kushwaha   25000      Sales  8595787618     2500.0
# 9   10  Abhishek     Yadav   95000  Marketing  8595787619     9500.0
# 10  11   Aaditya     Yadav   10000    Finance  8595787620     1000.0
# 11  12     Daksh   Chauhan   66000         IT  8595787621     6600.0
# 12  13     Ayush     Singh   30000      Sales  8595787622     3000.0
# ...

# %%
p=df.set_index('Name')
p
# Out:
#           Id  Lastname  Salary Department  Mobile no.  Taxsalary
# Name
# Anshu      1    Rajput   90000      Sales  8595787610     9000.0
# Manish     2     Kumar   62000  Marketing  8595787611     6200.0
# Aadil      3      Khan   70000    Finance  8595787612     7000.0
# Chandan    4    Thakur   80000         IT  8595787613     8000.0
# Aman       5     Anand   20000      Sales  8595787614     2000.0
# Badal      6     Singh   65000  Marketing  8595787615     6500.0
# Anil       7     Yadav   55000    Finance  8595787616     5500.0
# Akash      8     Verma   75000         IT  8595787617     7500.0
# Yash       9  Kushwaha   25000      Sales  8595787618     2500.0
# Abhishek  10     Yadav   95000  Marketing  8595787619     9500.0
# Aaditya   11     Yadav   10000    Finance  8595787620     1000.0
# Daksh     12   Chauhan   66000         IT  8595787621     6600.0
# Ayush     13     Singh   30000      Sales  8595787622     3000.0
# ...

# %%
t=p['Salary']
t
# Out:
# Name
# Anshu       90000
# Manish      62000
# Aadil       70000
# Chandan     80000
# Aman        20000
# Badal       65000
# Anil        55000
# Akash       75000
# Yash        25000
# Abhishek    95000
# Aaditya     10000
# Daksh       66000
# Ayush       30000
# Arun        89000
# Ashish      90000
# Shivam      91000
# Swati       92000
# Vineet      93000
# Sourav      94000
# Yogesh      95000
# Name: Salary, dtype: int64

# %%
type(t)
# Out:
# pandas.core.series.Series

# %%
t.plot.bar(figsize=(15,5),color='green')
# Out:
# <Axes: xlabel='Name'>

# %%
t.plot.barh(figsize=(15,5),color='green')
# Out:
# <Axes: ylabel='Name'>

# %%
y=p[['Salary','Taxsalary']]
y
# Out:
#           Salary  Taxsalary
# Name
# Anshu      90000     9000.0
# Manish     62000     6200.0
# Aadil      70000     7000.0
# Chandan    80000     8000.0
# Aman       20000     2000.0
# Badal      65000     6500.0
# Anil       55000     5500.0
# Akash      75000     7500.0
# Yash       25000     2500.0
# Abhishek   95000     9500.0
# Aaditya    10000     1000.0
# Daksh      66000     6600.0
# Ayush      30000     3000.0
# Arun       89000     8900.0
# Ashish     90000     9000.0
# Shivam     91000     9100.0
# Swati      92000     9200.0
# Vineet     93000     9300.0
# Sourav     94000     9400.0
# Yogesh     95000     9500.0

# %%
y.plot.bar(figsize=(15,5),stacked=True)
# Out:
# <Axes: xlabel='Name'>

# %%
y.plot.bar(figsize=(15,5))
# Out:
# <Axes: xlabel='Name'>

# %%
t.plot.pie(figsize=(15,8))
# Out:
# <Axes: ylabel='Salary'>

# %%
y.plot()
# Out:
# <Axes: xlabel='Name'>

# %%
g=df['Salary']
g
# Out:
# 0     90000
# 1     62000
# 2     70000
# 3     80000
# 4     20000
# 5     65000
# 6     55000
# 7     75000
# 8     25000
# 9     95000
# 10    10000
# 11    66000
# 12    30000
# 13    89000
# 14    90000
# 15    91000
# 16    92000
# 17    93000
# 18    94000
# 19    95000
# Name: Salary, dtype: int64

# %%
g.plot.box()
# Out:
# <Axes: >

# %%
q1=p['Salary'].quantile(0.25)
q1
# Out:
# np.float64(60250.0)

# %%
q2=p['Salary'].quantile(0.75)
q2
# Out:
# np.float64(91250.0)

# %%
h=q2-q1
h
# Out:
# np.float64(31000.0)

# %%
upper=q2+(1.5*h)
upper
# Out:
# np.float64(137750.0)

# %%
lower=q1-(1.5*h)
lower
# Out:
# np.float64(13750.0)

# %%
r=p[(p['Salary']>upper)|(p['Salary']<lower)]
r
# Out:
#          Id Lastname  Salary Department  Mobile no.  Taxsalary
# Name
# Aaditya  11    Yadav   10000    Finance  8595787620     1000.0

# %%
p1=p[(p['Salary']>=lower) & (p['Salary']<=upper)]
p1
# Out:
#           Id  Lastname  Salary Department  Mobile no.  Taxsalary
# Name
# Anshu      1    Rajput   90000      Sales  8595787610     9000.0
# Manish     2     Kumar   62000  Marketing  8595787611     6200.0
# Aadil      3      Khan   70000    Finance  8595787612     7000.0
# Chandan    4    Thakur   80000         IT  8595787613     8000.0
# Aman       5     Anand   20000      Sales  8595787614     2000.0
# Badal      6     Singh   65000  Marketing  8595787615     6500.0
# Anil       7     Yadav   55000    Finance  8595787616     5500.0
# Akash      8     Verma   75000         IT  8595787617     7500.0
# Yash       9  Kushwaha   25000      Sales  8595787618     2500.0
# Abhishek  10     Yadav   95000  Marketing  8595787619     9500.0
# Daksh     12   Chauhan   66000         IT  8595787621     6600.0
# Ayush     13     Singh   30000      Sales  8595787622     3000.0
# Arun      14     Singh   89000  Marketing  8595787623     8900.0
# ...

# %%
# p1[p1['Salary']<lower]

# %%
p1['Salary'].plot.box()
# Out:
# <Axes: >

# %%
# outlier remove
# p1['Salary'].plot.box(showfliers=False)

# %%
q1=p1['Salary'].quantile(0.25)
q1
# Out:
# np.float64(63500.0)

# %%
q2=p1['Salary'].quantile(0.75)
q2
# Out:
# np.float64(91500.0)

# %%
h=q2-q1
h
# Out:
# np.float64(28000.0)

# %%
upper1=q2+(1.5*h)
upper1
# Out:
# np.float64(133500.0)

# %%
lower1=q1-(1.5*h)
lower1
# Out:
# np.float64(21500.0)

# %%
r2=p1[(p1['Salary']>upper)|(p1['Salary']<lower)]
r2
# Out:
# Empty DataFrame
# Columns: [Id, Lastname, Salary, Department, Mobile no., Taxsalary]
# Index: []

# %%
len(r2)
# Out:
# 0

# %%
p1['Salary'].plot.box()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
t=df['Name']
t2=list(t)
t2
# Out:
# ['Anshu',
#  'Manish',
#  'Aadil',
#  'Chandan',
#  'Aman',
#  'Badal',
#  'Anil',
#  'Akash',
#  'Yash',
#  'Abhishek',
#  'Aaditya',
#  'Daksh',
#  'Ayush',
#  'Arun',
#  'Ashish',
#  'Shivam',
#  'Swati',
#  'Vineet',
#  'Sourav',
#  'Yogesh']

# %%
s=df['Salary']
s2=list(s)
s2
# Out:
# [90000,
#  62000,
#  70000,
#  80000,
#  20000,
#  65000,
#  55000,
#  75000,
#  25000,
#  95000,
#  10000,
#  66000,
#  30000,
#  89000,
#  90000,
#  91000,
#  92000,
#  93000,
#  94000,
#  95000]

# %%
p=['blue','red','green','yellow','orange','pink','black','brown','purple','magenta','blue','red','green','yellow','orange','pink','black','brown','purple','magenta']
p
# Out:
# ['blue',
#  'red',
#  'green',
#  'yellow',
#  'orange',
#  'pink',
#  'black',
#  'brown',
#  'purple',
#  'magenta',
#  'blue',
#  'red',
#  'green',
#  'yellow',
#  'orange',
#  'pink',
#  'black',
#  'brown',
#  'purple',
#  'magenta']

# %%
plt.figure(figsize=(15,8))
plt.barh(t2,s2,color=p)
plt.xlabel('Salary',size=20,color='red')
plt.ylabel('Name',size=20,color='red')
plt.xticks(rotation=30,size=12,color='green')
plt.yticks(rotation=30,size=12,color='green')
plt.title('Salary of Employees',size=20,color='red')

for index,value in enumerate(s2):
    plt.text(value,index,str(value))

plt.show()

# %%
plt.figure(figsize=(15,8))
plt.bar(t2,s2,color=p)
plt.xlabel('Name',size=20,color='red')
plt.ylabel('Salary',size=20,color='red')
plt.xticks(rotation=30,size=12,color='green')
plt.yticks(rotation=30,size=12,color='green')
plt.title('Salary of Employees',size=20,color='red')

# for index,value in enumerate(s2):
    # plt.text(value,index,str(value))

plt.show()

# %%
t2
# Out:
# ['Anshu',
#  'Manish',
#  'Aadil',
#  'Chandan',
#  'Aman',
#  'Badal',
#  'Anil',
#  'Akash',
#  'Yash',
#  'Abhishek',
#  'Aaditya',
#  'Daksh',
#  'Ayush',
#  'Arun',
#  'Ashish',
#  'Shivam',
#  'Swati',
#  'Vineet',
#  'Sourav',
#  'Yogesh']

# %%
s2
# Out:
# [90000,
#  62000,
#  70000,
#  80000,
#  20000,
#  65000,
#  55000,
#  75000,
#  25000,
#  95000,
#  10000,
#  66000,
#  30000,
#  89000,
#  90000,
#  91000,
#  92000,
#  93000,
#  94000,
#  95000]

# %%
e=(0,0,0.3,0,0,0,0.4,0,0,0,0,0,0,0.4,0,0,0.5,0,0,0)
plt.figure(figsize=(15,7))
plt.pie(s2,explode=e,labels=t2,autopct='%1.1f%%',shadow=True,colors=p)
plt.title('Employees Salary',size=15,color='Green')
plt.legend()
plt.show()

# %%
import pandas as pd
ipl={'Team':['Riders','Riders','Devils','Devils','Kings','Kings','Kings','Kings','Riders','Royals','Royals','Riders'],
     'Rank':[1,2,2,3,3,4,1,1,2,4,1,2],
     'Year':[2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
     'Points':[876,789,863,673,741,812,756,788,649,701,804,690]}
df=pd.DataFrame(ipl)
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     649
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
h=df.groupby('Team')
h

# %%
p=h['Points'].sum()
p
# Out:
# Team
# Devils    1536
# Kings     3097
# Riders    3004
# Royals    1505
# Name: Points, dtype: int64

# %%
g=pd.DataFrame(p)
g
# Out:
#         Points
# Team
# Devils    1536
# Kings     3097
# Riders    3004
# Royals    1505

# %%
n=g.reset_index()
n
# Out:
#      Team  Points
# 0  Devils    1536
# 1   Kings    3097
# 2  Riders    3004
# 3  Royals    1505

# %%
t=n['Team']
t2=list(t)
t2
# Out:
# ['Devils', 'Kings', 'Riders', 'Royals']

# %%
s=n['Points']
s2=list(s)
s2
# Out:
# [1536, 3097, 3004, 1505]

# %%
k=['blue','red','green','yellow']

# %%
plt.figure(figsize=(15,3))
plt.barh(t2,s2,color=k)
plt.xlabel('Team',size=20,color='red',fontweight='bold')
plt.ylabel('Points',size=20,color='red',fontweight='bold')
plt.xticks(rotation=30,size=12,color='green')
plt.yticks(rotation=30,size=12,color='green')
plt.title('Team Records Report',size=20,color='red',fontweight='bold')

for index,value in enumerate(s2):
    plt.text(value,index,str(value))

plt.show()

# %%
plt.figure(figsize=(15,3))
plt.plot(t2,s2,marker='*',color='green')
plt.xlabel('Team',size=20,color='red',fontweight='bold')
plt.ylabel('Points',size=20,color='red',fontweight='bold')
plt.xticks(rotation=30,size=12,color='green')
plt.yticks(rotation=30,size=12,color='green')
plt.title('Team Records Report',size=20,color='red',fontweight='bold')

for index,value in enumerate(s2):
    plt.text(
        t2[index],
        index,
        f"
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\asus\Desktop\Datasets\crime_dataset_india.csv")
df.head()
# Out:
#    Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0              1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1              2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2              3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3              4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4              5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
#
#         City  Crime Code Crime Description  Victim Age Victim Gender  \
# 0  Ahmedabad         576    IDENTITY THEFT          16             M
# 1    Chennai         128          HOMICIDE          37             M
# 2   Ludhiana         271        KIDNAPPING          48             F
# 3       Pune         170          BURGLARY          49             F
# 4       Pune         421         VANDALISM          30             F
#
#     Weapon Used   Crime Domain  Police Deployed Case Closed  Date Case Closed
# ...

# %%
df.shape
# Out:
# (40160, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40160 entries, 0 to 40159
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Report Number       40160 non-null  int64
#  1   Date Reported       40160 non-null  object
#  2   Date of Occurrence  40160 non-null  object
#  3   Time of Occurrence  40160 non-null  object
#  4   City                40160 non-null  object
#  5   Crime Code          40160 non-null  int64
#  6   Crime Description   40160 non-null  object
#  7   Victim Age          40160 non-null  int64
#  8   Victim Gender       40160 non-null  object
#  9   Weapon Used         34370 non-null  object
#  10  Crime Domain        40160 non-null  object
#  11  Police Deployed     40160 non-null  int64
#  12  Case Closed         40160 non-null  object
#  13  Date Case Closed    20062 non-null  object
# dtypes: int64(4), object(10)
# memory usage: 4.3+ MB

# %%
df.isnull()
# Out:
#        Report Number  Date Reported  Date of Occurrence  Time of Occurrence  \
# 0              False          False               False               False
# 1              False          False               False               False
# 2              False          False               False               False
# 3              False          False               False               False
# 4              False          False               False               False
# ...              ...            ...                 ...                 ...
# 40155          False          False               False               False
# 40156          False          False               False               False
# 40157          False          False               False               False
# 40158          False          False               False               False
# 40159          False          False               False               False
#
# ...

# %%
df.isnull().sum()
# Out:
# Report Number             0
# Date Reported             0
# Date of Occurrence        0
# Time of Occurrence        0
# City                      0
# Crime Code                0
# Crime Description         0
# Victim Age                0
# Victim Gender             0
# Weapon Used            5790
# Crime Domain              0
# Police Deployed           0
# Case Closed               0
# Date Case Closed      20098
# dtype: int64

# %%
df['Victim Gender'].value_counts()
# Out:
# Victim Gender
# F    22423
# M    13405
# X     4332
# Name: count, dtype: int64

# %%
data=df.groupby('City')
data

# %%
s=df['City'].value_counts()
s
# Out:
# City
# Delhi            5400
# Mumbai           4415
# Bangalore        3588
# Hyderabad        2881
# Kolkata          2518
# Chennai          2493
# Pune             2212
# Ahmedabad        1817
# Jaipur           1479
# Lucknow          1456
# Kanpur           1112
# Surat            1111
# Nagpur           1053
# Agra              764
# Ludhiana          761
# Visakhapatnam     728
# Thane             706
# Ghaziabad         704
# Indore            699
# Patna             695
# Bhopal            690
# Meerut            395
# Srinagar          371
# Nashik            366
# Vasai             362
# Varanasi          355
# Kalyan            355
# Faridabad         354
# Rajkot            320
# Name: count, dtype: int64

# %%
 s.plot.bar()
# Out:
# <Axes: xlabel='City'>

# %%
v=df[df['City']=='Delhi']     # EDA ==Elebraute data analytics
v
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 5                  6  02-01-2020 03:00   01-01-2020 05:00   01-01-2020 17:09
# 10                11  02-01-2020 13:00   01-01-2020 10:00   01-01-2020 19:42
# 32                33  03-01-2020 04:00   01-02-2020 08:00   03-01-2020 03:01
# 42                43  03-01-2020 03:00   01-02-2020 18:00   03-01-2020 09:30
# 46                47  05-01-2020 04:00   01-02-2020 22:00   03-01-2020 09:55
# ...              ...               ...                ...                ...
# 40131          40132  30-07-2024 08:00   07-30-2024 03:00   30-07-2024 22:45
# 40134          40135  31-07-2024 02:00   07-30-2024 06:00   30-07-2024 12:21
# 40142          40143  01-08-2024 22:00   07-30-2024 14:00   30-07-2024 16:55
# 40146          40147  02-08-2024 09:00   07-30-2024 18:00   30-07-2024 19:32
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
v['Victim Gender'].value_counts()
# Out:
# Victim Gender
# F    2956
# M    1858
# X     586
# Name: count, dtype: int64

# %%
p=v['Weapon Used'].value_counts()
p
# Out:
# Weapon Used
# Firearm         811
# Knife           773
# Poison          769
# Blunt Object    769
# Explosives      763
# Other           724
# Name: count, dtype: int64

# %%
g=v[v['Victim Gender']=='M']
g
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 5                  6  02-01-2020 03:00   01-01-2020 05:00   01-01-2020 17:09
# 10                11  02-01-2020 13:00   01-01-2020 10:00   01-01-2020 19:42
# 42                43  03-01-2020 03:00   01-02-2020 18:00   03-01-2020 09:30
# 53                54  05-01-2020 10:00   01-03-2020 05:00   03-01-2020 18:47
# 75                76  06-01-2020 00:00   01-04-2020 03:00   04-01-2020 20:57
# ...              ...               ...                ...                ...
# 40050          40051  29-07-2024 07:00   07-26-2024 18:00   26-07-2024 19:15
# 40063          40064  29-07-2024 17:00   07-27-2024 07:00   28-07-2024 03:39
# 40074          40075  28-07-2024 08:00   07-27-2024 18:00   27-07-2024 23:43
# 40134          40135  31-07-2024 02:00   07-30-2024 06:00   30-07-2024 12:21
# 40142          40143  01-08-2024 22:00   07-30-2024 14:00   30-07-2024 16:55
#
# ...

# %%
g2=v[v['Victim Gender']=='F']
g2
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 32                33  03-01-2020 04:00   01-02-2020 08:00   03-01-2020 03:01
# 46                47  05-01-2020 04:00   01-02-2020 22:00   03-01-2020 09:55
# 80                81  05-01-2020 03:00   01-04-2020 08:00   04-01-2020 23:33
# 109              110  05-01-2020 17:00   01-05-2020 13:00   05-01-2020 23:32
# 111              112  08-01-2020 05:00   01-05-2020 15:00   06-01-2020 07:02
# ...              ...               ...                ...                ...
# 40120          40121  31-07-2024 02:00   07-29-2024 16:00   30-07-2024 08:35
# 40122          40123  01-08-2024 16:00   07-29-2024 18:00   30-07-2024 09:02
# 40131          40132  30-07-2024 08:00   07-30-2024 03:00   30-07-2024 22:45
# 40146          40147  02-08-2024 09:00   07-30-2024 18:00   30-07-2024 19:32
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
g3=v[v['Victim Gender']=='X']
g3
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 9300            9301  24-01-2021 05:00   01-22-2021 12:00   22-01-2021 12:38
# 9329            9330  24-01-2021 11:00   01-23-2021 17:00   23-01-2021 21:01
# 16477          16478  18-11-2021 03:00   11-17-2021 13:00   18-11-2021 04:32
# 16496          16497  19-11-2021 01:00   11-18-2021 08:00   19-11-2021 05:59
# 16508          16509  20-11-2021 17:00   11-18-2021 20:00   19-11-2021 04:20
# ...              ...               ...                ...                ...
# 28995          28996  25-04-2023 14:00   04-23-2023 03:00   23-04-2023 20:20
# 29044          29045  26-04-2023 06:00   04-25-2023 04:00   25-04-2023 07:07
# 29132          29133  01-05-2023 00:00   04-28-2023 20:00   28-04-2023 22:27
# 29141          29142  29-04-2023 19:00   04-29-2023 05:00   29-04-2023 15:15
# 29145          29146  29-04-2023 11:00   04-29-2023 09:00   29-04-2023 15:48
#
# ...

# %%
b=g[g['Crime Description']=='ROBBERY']
b
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 417              418  21-01-2020 02:00   01-18-2020 09:00   19-01-2020 04:50
# 734              735  02-02-2020 11:00   01-31-2020 14:00   01-02-2020 06:43
# 1110            1111  17-02-2020 15:00   02-16-2020 06:00   16-02-2020 06:53
# 2498            2499  15-04-2020 13:00   04-14-2020 02:00   14-04-2020 12:05
# 2582            2583  20-04-2020 13:00   04-17-2020 14:00   18-04-2020 12:22
# ...              ...               ...                ...                ...
# 39036          39037  16-06-2024 01:00   06-14-2024 12:00   14-06-2024 17:46
# 39099          39100  19-06-2024 22:00   06-17-2024 03:00   17-06-2024 12:52
# 39342          39343  27-06-2024 19:00   06-27-2024 06:00   27-06-2024 16:34
# 39735          39736  16-07-2024 05:00   07-13-2024 15:00   14-07-2024 05:30
# 39840          39841  20-07-2024 13:00   07-18-2024 00:00   18-07-2024 12:30
#
# ...

# %%
b2=g2[g2['Crime Description']=='ROBBERY']
b2
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 46                47  05-01-2020 04:00   01-02-2020 22:00   03-01-2020 09:55
# 606              607  27-01-2020 15:00   01-26-2020 06:00   26-01-2020 17:37
# 1105            1106  18-02-2020 15:00   02-16-2020 01:00   16-02-2020 03:36
# 1444            1445  03-03-2020 16:00   03-01-2020 04:00   01-03-2020 06:20
# 1553            1554  07-03-2020 18:00   03-05-2020 17:00   06-03-2020 07:13
# ...              ...               ...                ...                ...
# 38667          38668  01-06-2024 18:00   05-30-2024 03:00   31-05-2024 00:47
# 38995          38996  13-06-2024 19:00   06-12-2024 19:00   13-06-2024 12:20
# 39634          39635  12-07-2024 00:00   07-09-2024 10:00   10-07-2024 01:13
# 40131          40132  30-07-2024 08:00   07-30-2024 03:00   30-07-2024 22:45
# 40146          40147  02-08-2024 09:00   07-30-2024 18:00   30-07-2024 19:32
#
# ...

# %%
b3=g3[g3['Crime Description']=='ROBBERY']
b3.head()
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 16799          16800  02-12-2021 07:00   11-30-2021 23:00   01-12-2021 07:02
# 16887          16888  05-12-2021 08:00   12-04-2021 15:00   04-12-2021 19:33
# 17912          17913  17-01-2022 04:00   01-16-2022 08:00   16-01-2022 15:12
# 18086          18087  25-01-2022 17:00   01-23-2022 14:00   24-01-2022 13:32
# 18334          18335  03-02-2022 20:00   02-02-2022 22:00   03-02-2022 21:50
#
#         City  Crime Code Crime Description  Victim Age Victim Gender  \
# 16799  Delhi         191           ROBBERY          70             X
# 16887  Delhi         155           ROBBERY          48             X
# 17912  Delhi         297           ROBBERY          65             X
# 18086  Delhi         526           ROBBERY          16             X
# 18334  Delhi         235           ROBBERY          73             X
#
#         Weapon Used   Crime Domain  Police Deployed Case Closed  \
# ...

# %%
b3.shape
# Out:
# (33, 14)

# %%
n=v['Crime Description'].value_counts()
n
# Out:
# Crime Description
# FIREARM OFFENSE        291
# CYBERCRIME             286
# FRAUD                  281
# ROBBERY                280
# DRUG OFFENSE           278
# DOMESTIC VIOLENCE      275
# IDENTITY THEFT         272
# HOMICIDE               270
# KIDNAPPING             260
# VANDALISM              256
# COUNTERFEITING         254
# BURGLARY               254
# SEXUAL ASSAULT         254
# ILLEGAL POSSESSION     250
# VEHICLE - STOLEN       247
# PUBLIC INTOXICATION    246
# EXTORTION              246
# SHOPLIFTING            244
# ASSAULT                231
# ARSON                  227
# TRAFFIC VIOLATION      198
# Name: count, dtype: int64

# %%
d=df['Crime Description'].unique()
d
# Out:
# array(['IDENTITY THEFT', 'HOMICIDE', 'KIDNAPPING', 'BURGLARY',
#        'VANDALISM', 'ASSAULT', 'VEHICLE - STOLEN', 'COUNTERFEITING',
#        'EXTORTION', 'PUBLIC INTOXICATION', 'FRAUD', 'SEXUAL ASSAULT',
#        'DRUG OFFENSE', 'ARSON', 'CYBERCRIME', 'TRAFFIC VIOLATION',
#        'SHOPLIFTING', 'ILLEGAL POSSESSION', 'FIREARM OFFENSE', 'ROBBERY',
#        'DOMESTIC VIOLENCE'], dtype=object)

# %%
h=df['Victim Age'].value_counts()
h
# Out:
# Victim Age
# 25    636
# 22    636
# 35    619
# 34    612
# 40    608
#      ...
# 58    538
# 57    535
# 12    534
# 71    531
# 52    523
# Name: count, Length: 70, dtype: int64

# %%
r=pd.DataFrame(h)
r
# Out:
#             count
# Victim Age
# 25            636
# 22            636
# 35            619
# 34            612
# 40            608
# ...           ...
# 58            538
# 57            535
# 12            534
# 71            531
# 52            523
#
# [70 rows x 1 columns]

# %%
b=r.sort_values('count',ascending=False).head(5)
b
# Out:
#             count
# Victim Age
# 25            636
# 22            636
# 35            619
# 34            612
# 40            608

# %%
s=v['Case Closed'].value_counts()
s
# Out:
# Case Closed
# No     2754
# Yes    2646
# Name: count, dtype: int64

# %%
s=
# Out:
#   Cell In[27], line 1
#     s=
#       ^
# SyntaxError: invalid syntax

# %%
b=v[v['Crime Description']== 'ROBBERY']
b
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 46                47  05-01-2020 04:00   01-02-2020 22:00   03-01-2020 09:55
# 417              418  21-01-2020 02:00   01-18-2020 09:00   19-01-2020 04:50
# 606              607  27-01-2020 15:00   01-26-2020 06:00   26-01-2020 17:37
# 734              735  02-02-2020 11:00   01-31-2020 14:00   01-02-2020 06:43
# 1105            1106  18-02-2020 15:00   02-16-2020 01:00   16-02-2020 03:36
# ...              ...               ...                ...                ...
# 39634          39635  12-07-2024 00:00   07-09-2024 10:00   10-07-2024 01:13
# 39735          39736  16-07-2024 05:00   07-13-2024 15:00   14-07-2024 05:30
# 39840          39841  20-07-2024 13:00   07-18-2024 00:00   18-07-2024 12:30
# 40131          40132  30-07-2024 08:00   07-30-2024 03:00   30-07-2024 22:45
# 40146          40147  02-08-2024 09:00   07-30-2024 18:00   30-07-2024 19:32
#
# ...

# %%
b['Case Closed'].value_counts()
# Out:
# Case Closed
# No     140
# Yes    140
# Name: count, dtype: int64

# %%
n=v[v['Case Closed']=='Yes']
n
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 5                  6  02-01-2020 03:00   01-01-2020 05:00   01-01-2020 17:09
# 10                11  02-01-2020 13:00   01-01-2020 10:00   01-01-2020 19:42
# 42                43  03-01-2020 03:00   01-02-2020 18:00   03-01-2020 09:30
# 75                76  06-01-2020 00:00   01-04-2020 03:00   04-01-2020 20:57
# 80                81  05-01-2020 03:00   01-04-2020 08:00   04-01-2020 23:33
# ...              ...               ...                ...                ...
# 40120          40121  31-07-2024 02:00   07-29-2024 16:00   30-07-2024 08:35
# 40122          40123  01-08-2024 16:00   07-29-2024 18:00   30-07-2024 09:02
# 40131          40132  30-07-2024 08:00   07-30-2024 03:00   30-07-2024 22:45
# 40146          40147  02-08-2024 09:00   07-30-2024 18:00   30-07-2024 19:32
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
n1=v[v['Case Closed']=='No']
n1
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 32                33  03-01-2020 04:00   01-02-2020 08:00   03-01-2020 03:01
# 46                47  05-01-2020 04:00   01-02-2020 22:00   03-01-2020 09:55
# 53                54  05-01-2020 10:00   01-03-2020 05:00   03-01-2020 18:47
# 109              110  05-01-2020 17:00   01-05-2020 13:00   05-01-2020 23:32
# 111              112  08-01-2020 05:00   01-05-2020 15:00   06-01-2020 07:02
# ...              ...               ...                ...                ...
# 40070          40071  29-07-2024 01:00   07-27-2024 14:00   28-07-2024 07:08
# 40095          40096  30-07-2024 12:00   07-28-2024 15:00   29-07-2024 02:34
# 40104          40105  29-07-2024 16:00   07-29-2024 00:00   29-07-2024 11:54
# 40134          40135  31-07-2024 02:00   07-30-2024 06:00   30-07-2024 12:21
# 40142          40143  01-08-2024 22:00   07-30-2024 14:00   30-07-2024 16:55
#
# ...

# %%
# Delhi me cybercrime 
q=g[g['Crime Description']=='CYBERCRIME']
q
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
#
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 181              182  10-01-2020 13:00   01-08-2020 13:00   09-01-2020 12:16
# 351              352  15-01-2020 19:00   01-15-2020 15:00   16-01-2020 01:58
# 453              454  22-01-2020 09:00   01-19-2020 21:00   19-01-2020 21:25
# 633              634  28-01-2020 05:00   01-27-2020 09:00   27-01-2020 19:36
# 684              685  01-02-2020 09:00   01-29-2020 12:00   30-01-2020 02:17
# ...              ...               ...                ...                ...
# 39491          39492  05-07-2024 04:00   07-03-2024 11:00   04-07-2024 02:52
# 39517          39518  06-07-2024 00:00   07-04-2024 13:00   05-07-2024 10:27
# 39772          39773  16-07-2024 08:00   07-15-2024 04:00   15-07-2024 14:02
# 39796          39797  17-07-2024 16:00   07-16-2024 04:00   16-07-2024 11:07
# 40034          40035  27-07-2024 05:00   07-26-2024 02:00   26-07-2024 07:53
#
# ...

# %%
q2.shape
# Out:
# (115, 14)

# %%
q3=g3[g3['Crime Description']=='CYBERCRIME']
q3.head()
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 16510          16511  21-11-2021 03:00   11-18-2021 22:00   18-11-2021 22:04
# 16840          16841  03-12-2021 05:00   12-02-2021 16:00   02-12-2021 21:35
# 17131          17132  15-12-2021 09:00   12-14-2021 19:00   14-12-2021 22:26
# 17315          17316  24-12-2021 18:00   12-22-2021 11:00   22-12-2021 16:39
# 17496          17497  31-12-2021 09:00   12-30-2021 00:00   30-12-2021 02:46
#
#          City  Crime Code Crime Description  Victim Age Victim Gender  \
# 16510  Mumbai         489        CYBERCRIME          23             X
# 16840  Mumbai         436        CYBERCRIME          57             X
# 17131  Mumbai         444        CYBERCRIME          41             X
# 17315  Mumbai         311        CYBERCRIME          24             X
# 17496  Mumbai         293        CYBERCRIME          72             X
#
#       Weapon Used Crime Domain  Police Deployed Case Closed  Date Case Closed
# ...

# %%
q3.shape
# Out:
# (23, 14)

# %%
# to_datetime use hota hai date colom ko initialise krne ke liya kyuki pc ko nhi pata ki ye column date time lekhi hai.
df['Date of Occurrence']=pd.to_datetime(df['Date of Occurrence'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40160 entries, 0 to 40159
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Report Number       40160 non-null  int64
#  1   Date Reported       40160 non-null  object
#  2   Date of Occurrence  40160 non-null  datetime64[ns]
#  3   Time of Occurrence  40160 non-null  object
#  4   City                40160 non-null  object
#  5   Crime Code          40160 non-null  int64
#  6   Crime Description   40160 non-null  object
#  7   Victim Age          40160 non-null  int64
#  8   Victim Gender       40160 non-null  object
#  9   Weapon Used         34370 non-null  object
#  10  Crime Domain        40160 non-null  object
#  11  Police Deployed     40160 non-null  int64
#  12  Case Closed         40160 non-null  object
#  13  Date Case Closed    20062 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(9)
# memory usage: 4.3+ MB

# %%
# abb ye date me month jo bhi hogi usko ek new colom me likh dega or ek new coloum add krage months name ka.
df['Months']=df['Date of Occurrence'].dt.month_name()

# %%
df
# Out:
#        Report Number     Date Reported  Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00 2020-01-01 00:00:00   01-01-2020 01:11
# 1                  2  01-01-2020 19:00 2020-01-01 01:00:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00 2020-01-01 02:00:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00 2020-01-01 03:00:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00 2020-01-01 04:00:00   01-01-2020 16:51
# ...              ...               ...                 ...                ...
# 40155          40156  01-08-2024 16:00 2024-07-31 03:00:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00 2024-07-31 04:00:00   31-07-2024 04:14
# 40157          40158  02-08-2024 03:00 2024-07-31 05:00:00   31-07-2024 21:33
# 40158          40159  01-08-2024 19:00 2024-07-31 06:00:00   31-07-2024 11:05
# 40159          40160  31-07-2024 17:00 2024-07-31 07:00:00   31-07-2024 17:19
#
# ...

# %%
df['Months'].value_counts()
# Out:
# Months
# January      3720
# March        3720
# May          3720
# July         3704
# April        3600
# June         3600
# February     3408
# August       2976
# October      2976
# December     2976
# September    2880
# November     2880
# Name: count, dtype: int64

# %%
m=df[df['Months']=='January']   
m
# Out:
#        Report Number     Date Reported  Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00 2020-01-01 00:00:00   01-01-2020 01:11
# 1                  2  01-01-2020 19:00 2020-01-01 01:00:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00 2020-01-01 02:00:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00 2020-01-01 03:00:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00 2020-01-01 04:00:00   01-01-2020 16:51
# ...              ...               ...                 ...                ...
# 35803          35804  02-02-2024 02:00 2024-01-31 19:00:00   31-01-2024 21:40
# 35804          35805  01-02-2024 15:00 2024-01-31 20:00:00   01-02-2024 06:05
# 35805          35806  02-02-2024 18:00 2024-01-31 21:00:00   01-02-2024 15:30
# 35806          35807  02-02-2024 19:00 2024-01-31 22:00:00   01-02-2024 04:28
# 35807          35808  02-02-2024 12:00 2024-01-31 23:00:00   01-02-2024 16:45
#
# ...

# %%
m['Victim Gender'].value_counts()
# Out:
# Victim Gender
# F    1954
# M    1220
# X     546
# Name: count, dtype: int64

# %%
f=df['Months'].value_counts(ascending=True)
f
# Out:
# Months
# September    2880
# November     2880
# August       2976
# October      2976
# December     2976
# February     3408
# April        3600
# June         3600
# July         3704
# January      3720
# March        3720
# May          3720
# Name: count, dtype: int64

# %%
df['Months'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
f.plot.bar()
# Out:
# <Axes: xlabel='Months'>

# %%
df['Year']=df['Date of Occurrence'].dt.year

# %%
df
# Out:
#        Report Number     Date Reported  Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00 2020-01-01 00:00:00   01-01-2020 01:11
# 1                  2  01-01-2020 19:00 2020-01-01 01:00:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00 2020-01-01 02:00:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00 2020-01-01 03:00:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00 2020-01-01 04:00:00   01-01-2020 16:51
# ...              ...               ...                 ...                ...
# 40155          40156  01-08-2024 16:00 2024-07-31 03:00:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00 2024-07-31 04:00:00   31-07-2024 04:14
# 40157          40158  02-08-2024 03:00 2024-07-31 05:00:00   31-07-2024 21:33
# 40158          40159  01-08-2024 19:00 2024-07-31 06:00:00   31-07-2024 11:05
# 40159          40160  31-07-2024 17:00 2024-07-31 07:00:00   31-07-2024 17:19
#
# ...

# %%
d=df['Year'].value_counts()
d
# Out:
# Year
# 2020    8784
# 2021    8760
# 2022    8760
# 2023    8760
# 2024    5096
# Name: count, dtype: int64

# %%
d.plot.bar()
# Out:
# <Axes: xlabel='Year'>

# %%
m2=df[df['Year']==2020]
m2
# Out:
#       Report Number     Date Reported  Date of Occurrence Time of Occurrence  \
# 0                 1  02-01-2020 00:00 2020-01-01 00:00:00   01-01-2020 01:11
# 1                 2  01-01-2020 19:00 2020-01-01 01:00:00   01-01-2020 06:26
# 2                 3  02-01-2020 05:00 2020-01-01 02:00:00   01-01-2020 14:30
# 3                 4  01-01-2020 05:00 2020-01-01 03:00:00   01-01-2020 14:46
# 4                 5  01-01-2020 21:00 2020-01-01 04:00:00   01-01-2020 16:51
# ...             ...               ...                 ...                ...
# 8779           8780  01-01-2021 13:00 2020-12-31 19:00:00   01-01-2021 17:53
# 8780           8781  01-01-2021 13:00 2020-12-31 20:00:00   01-01-2021 10:01
# 8781           8782  02-01-2021 12:00 2020-12-31 21:00:00   01-01-2021 00:02
# 8782           8783  02-01-2021 07:00 2020-12-31 22:00:00   01-01-2021 06:22
# 8783           8784  03-01-2021 06:00 2020-12-31 23:00:00   01-01-2021 06:02
#
# ...

# %%
m2['Crime Description'].value_counts()
# Out:
# Crime Description
# VANDALISM              457
# FIREARM OFFENSE        446
# HOMICIDE               442
# BURGLARY               440
# DOMESTIC VIOLENCE      433
# IDENTITY THEFT         429
# COUNTERFEITING         427
# VEHICLE - STOLEN       423
# FRAUD                  421
# ASSAULT                420
# SHOPLIFTING            419
# ROBBERY                417
# CYBERCRIME             416
# KIDNAPPING             415
# EXTORTION              409
# ILLEGAL POSSESSION     406
# ARSON                  404
# TRAFFIC VIOLATION      400
# SEXUAL ASSAULT         393
# PUBLIC INTOXICATION    386
# DRUG OFFENSE           381
# Name: count, dtype: int64

# %%
m2['Crime Description'].value_counts(ascending=True)
# Out:
# Crime Description
# DRUG OFFENSE           381
# PUBLIC INTOXICATION    386
# SEXUAL ASSAULT         393
# TRAFFIC VIOLATION      400
# ARSON                  404
# ILLEGAL POSSESSION     406
# EXTORTION              409
# KIDNAPPING             415
# CYBERCRIME             416
# ROBBERY                417
# SHOPLIFTING            419
# ASSAULT                420
# FRAUD                  421
# VEHICLE - STOLEN       423
# COUNTERFEITING         427
# IDENTITY THEFT         429
# DOMESTIC VIOLENCE      433
# BURGLARY               440
# HOMICIDE               442
# FIREARM OFFENSE        446
# VANDALISM              457
# Name: count, dtype: int64

# %%
# kis month me kitne crime hue.
month_crime = df.groupby("Months")["Report Number"].count()
month_crime
# Out:
# Months
# April        3600
# August       2976
# December     2976
# February     3408
# January      3720
# July         3704
# June         3600
# March        3720
# May          3720
# November     2880
# October      2976
# September    2880
# Name: Report Number, dtype: int64

# %%
month_crime.plot(marker='o')
plt.title("Monthly Crime Trend")
plt.xlabel("Month")
plt.ylabel("Number of Crimes")
plt.show()

# %%
# months vise kon sa crime kitne hue
df.groupby("Months")["Crime Domain"].value_counts()
# Out:
# Months     Crime Domain
# April      Other Crime         2053
#            Violent Crime       1043
#            Fire Accident        331
#            Traffic Fatality     173
# August     Other Crime         1708
#            Violent Crime        830
#            Fire Accident        302
#            Traffic Fatality     136
# December   Other Crime         1706
#            Violent Crime        848
#            Fire Accident        262
#            Traffic Fatality     160
# February   Other Crime         1973
#            Violent Crime        937
#            Fire Accident        356
#            Traffic Fatality     142
# January    Other Crime         2175
#            Violent Crime       1041
#            Fire Accident        346
#            Traffic Fatality     158
# July       Other Crime         2086
#            Violent Crime       1079
#            Fire Accident        349
#            Traffic Fatality     190
# June       Other Crime         2022
# ...

# %%
# kis months me average victim age kya thi
df.groupby("Months")["Victim Age"].mean()
# Out:
# Months
# April        44.546667
# August       44.292003
# December     44.465054
# February     44.479460
# January      44.558602
# July         44.165497
# June         44.496111
# March        44.427957
# May          44.364516
# November     43.805556
# October      45.327621
# September    45.061806
# Name: Victim Age, dtype: float64

# %%
# Case closer percentage rate.
df.groupby("Months")["Case Closed"].value_counts()
# Out:
# Months     Case Closed
# April      No             1814
#            Yes            1786
# August     Yes            1500
#            No             1476
# December   No             1497
#            Yes            1479
# February   Yes            1705
#            No             1703
# January    No             1870
#            Yes            1850
# July       No             1922
#            Yes            1782
# June       Yes            1860
#            No             1740
# March      No             1873
#            Yes            1847
# May        Yes            1862
#            No             1858
# November   No             1449
#            Yes            1431
# October    No             1507
#            Yes            1469
# September  Yes            1491
#            No             1389
# Name: count, dtype: int64

# %%
# kis month me kon ka crime kitne bar hue.
C=pd.crosstab(df['Months'], df['Crime Domain'])
C
# Out:
# Crime Domain  Fire Accident  Other Crime  Traffic Fatality  Violent Crime
# Months
# April                   331         2053               173           1043
# August                  302         1708               136            830
# December                262         1706               160            848
# February                356         1973               142            937
# January                 346         2175               158           1041
# July                    349         2086               190           1079
# June                    352         2022               186           1040
# March                   349         2163               167           1041
# May                     378         2089               176           1077
# November                252         1637               129            862
# October                 288         1677               163            848
# September               260         1659               135            826

# %%
C.plot.bar()
# Out:
# <Axes: xlabel='Months'>

# %%
# months me konsa weapon or kitne bar use hua hai.
k=pd.crosstab(df['Months'], df['Weapon Used'])
k
# Out:
# Weapon Used  Blunt Object  Explosives  Firearm  Knife  Other  Poison
# Months
# April                 476         537      511    552    498     508
# August                416         449      399    427    390     442
# December              435         418      400    411    423     417
# February              484         477      483    500    479     486
# January               547         512      491    541    576     497
# July                  508         524      573    520    515     538
# June                  529         477      476    576    525     501
# March                 498         520      538    570    499     554
# May                   603         544      524    512    503     531
# November              419         438      407    391    424     399
# October               402         434      418    422    430     435
# September             420         421      423    413    414     420

# %%
k.plot.bar()
# Out:
# <Axes: xlabel='Months'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Months',hue='Crime Description',data=df)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Year',hue='Crime Description',data=df)
plt.show()

# %%
# Count the unique values.
df['City'].nunique()
# Out:
# 29

# %%
v=df[['City','Year','Crime Description']].pivot_table(index='City',columns='Year',aggfunc="count")
v
# Out:
#               Crime Description
# Year                       2020  2021  2022  2023 2024
# City
# Agra                        178   155   166   162  103
# Ahmedabad                   411   422   365   402  217
# Bangalore                   775   790   789   782  452
# Bhopal                      152   148   127   167   96
# Chennai                     523   553   579   551  287
# Delhi                      1188  1198  1208  1085  721
# Faridabad                    74    73    77    79   51
# Ghaziabad                   159   155   143   165   82
# Hyderabad                   632   655   608   662  324
# Indore                      164   155   154   135   91
# Jaipur                      329   355   309   299  187
# Kalyan                       80    70    94    72   39
# Kanpur                      243   224   268   237  140
# Kolkata                     569   534   553   526  336
# Lucknow                     310   334   292   351  169
# ...

# %%
v.plot.bar(figsize=(15,5))
plt.show()

# %%
v2=df[['City','Year','Crime Description']].pivot_table(index='City',columns='Crime Description',aggfunc="count")
v2
# Out:
#                    Year                                             \
# Crime Description ARSON ASSAULT BURGLARY COUNTERFEITING CYBERCRIME
# City
# Agra                 43      47       32             40         32
# Ahmedabad            80     104       94             84         87
# Bangalore           154     175      187            176        155
# Bhopal               38      43       23             29         31
# Chennai             138     101      134            115        117
# Delhi               227     231      254            254        286
# Faridabad            19      25       11             14         13
# Ghaziabad            35      30       37             32         27
# Hyderabad           152     121      140            136        139
# Indore               28      39       31             32         34
# Jaipur               61      63       62             87         76
# Kalyan               13      20       14             16         15
# ...

# %%
v2.plot.bar(figsize=(18,5))
plt.show()

# %%
p=df['Weapon Used'].unique()
p
# Out:
# array(['Blunt Object', 'Poison', 'Firearm', 'Other', 'Knife',
#        'Explosives', nan], dtype=object)

# %%
v3=df[['City','Year','Weapon Used']].pivot_table(index='City',columns='Weapon Used',aggfunc="count")
v3
# Out:
#                       Year
# Weapon Used   Blunt Object Explosives Firearm Knife Other Poison
# City
# Agra                   105        105     116    99   103    116
# Ahmedabad              234        292     242   262   272    255
# Bangalore              546        525     469   479   509    542
# Bhopal                  93         94     105   108   104     83
# Chennai                345        351     336   402   344    381
# Delhi                  769        763     811   773   724    769
# Faridabad               43         49      43    55    61     50
# Ghaziabad               98        100      87    97   104    109
# Hyderabad              404        433     387   401   417    417
# Indore                  99        111      95    97    96    106
# Jaipur                 217        219     214   219   206    193
# Kalyan                  41         58      46    63    45     52
# Kanpur                 156        166     153   146   178    153
# ...

# %%
v3.plot.bar(figsize=(15,8))
plt.show()

# %%
v4=df.pivot_table(index=['City','Year'],columns='Crime Description',aggfunc="count")
v4
# Out:
#                    Case Closed                                             \
# Crime Description        ARSON ASSAULT BURGLARY COUNTERFEITING CYBERCRIME
# City          Year
# Agra          2020        10.0    13.0     10.0           10.0        5.0
#               2021         6.0     7.0      5.0            8.0        2.0
#               2022        12.0     8.0      4.0            8.0        9.0
#               2023        11.0    13.0      8.0            7.0        9.0
#               2024         4.0     6.0      5.0            7.0        7.0
# ...                        ...     ...      ...            ...        ...
# Visakhapatnam 2020        10.0     7.0      5.0            6.0        7.0
#               2021        10.0    13.0      9.0            2.0       10.0
#               2022         9.0     4.0      7.0            6.0       12.0
#               2023         7.0     6.0      5.0            4.0        4.0
# ...

# %%
# v4.plot.barh(figsize=(18,15))
# plt.show()

# %%
v41=df[['City','Victim Gender','Weapon Used']].pivot_table(index='City',columns='Victim Gender',aggfunc="count")
v41
# Out:
#               Weapon Used
# Victim Gender           F     M    X
# City
# Agra                  388   197   59
# Ahmedabad             895   501  161
# Bangalore            1741   986  343
# Bhopal                314   217   56
# Chennai              1148   773  238
# Delhi                2513  1605  491
# Faridabad             174    97   30
# Ghaziabad             330   211   54
# Hyderabad            1343   836  280
# Indore                331   205   68
# Jaipur                719   422  127
# Kalyan                171    90   44
# Kanpur                526   308  118
# Kolkata              1195   727  228
# Lucknow               715   415  125
# Ludhiana              388   195   71
# Meerut                188   119   31
# Mumbai               2121  1227  418
# Nagpur                526   275  108
# Nashik                168   110   35
# Patna                 345   191   67
# Pune                 1049   617  226
# Rajkot                155    95   24
# ...

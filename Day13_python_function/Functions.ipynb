# %%
# function in python
Functions in Python are named, reusable blocks of code that perform specific tasks, helping to organize programs, reduce redundancy (the "DRY" principle), and improve code readability and modularity. 
Defining and Calling a Function
Functions are defined using the def keyword, followed by a function name, parentheses (), and a colon :. The function body is indented below the definiti

# %%
# Variable
s=10

# %%
s
# Out:
# 10

# %%
# Constraint
PI=3.14

# %%
PI
# Out:
# 3.14

# %%
x=123
type(x)
# Out:
# int

# %%
x='Chandan'
type(x)
# Out:
# str

# %%
x=True
type(x)
# Out:
# bool

# %%
x=1.34
type(x)
# Out:
# float

# %%
x='A'
type(x)
# Out:
# str

# %%
h=[1,2,3,4,5,6,7,8]
type(h)
# Out:
# list

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# Control structure
# Decision making  -- if, else, 
# looping         -- for ,while
# Jumping        -- break, continue ,pass

# %%
age=int(input("Enter the age"))
if (age>18):
    print("Eligible for vote")
elif(age<10):
    print("You are a kid")
else:
    print("not eligible")
# Out:
# Enter the age 8
# You are a kid

# %%
for i in range(8):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
count = 1
while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
h=[1,2,'chsndn',12.3]
print(h[1])
# Out:
# 2

# %%
h=[1,2,'chsndn',12.3]
h[2]=5
print(h)
# Out:
# [1, 2, 5, 12.3]

# %%
# std={
#     "Name": "Chadan","Anil"
#     "Id": 20122,20122}
# print(std)
# type(std)

# %%
# type of files
# text file   -- csv_file
# binary file    --images,video
# .bin file     --
# files is lies in directoryies
# os model is used to work with directories
# directory is a container where we can store the files

# %%
# import os
# os.pathexists()     --for check the directories exist
# these two way to handle the directories

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\asus\\Documents\\data-analytics-learning-journey\\Day01_IBM'

# %%
# for change the directories
# os.chdir()      --for change the directories
# os.listdir()    --for list the directories
# os.mkdir()     --for make 
# os.rmdir()    --for remove
# Out:
# ['.ipynb_checkpoints', 'IBM.ipynb']

# %%
# two type of path
# related path      -- file.txt
# appslute path   --c:/user/downloads/

# %%
# file
# open("filename","mode")
# used r for read files
# used w =for write any files
# used a for append 
# used x for create file
# used rt for read and write
# used b for binary file
# for read multiples lines use file.readlines

# %%
file= open("example.txt","w")
file.write("this is file handling")
file.close()
# content=file.readlines
# line=file.readline
# line=file.readlines
# print(content)

# %%
# os.path.exists()

# %%
file=open("example.txt","r")
content=file.readlines
line=file.readline
line=file.readlines
print(content)
# Out:
# <built-in method readlines of _io.TextIOWrapper object at 0x000001906B3F51C0>

# %%
file=open("example.txt","a")
file.write("This line is append")
file.close()

# %%
content=file.readlines
line=file.readline
line=file.readlines
print(content)
# Out:
# <built-in method readlines of _io.TextIOWrapper object at 0x000001906B3F4AC0>

# %%
with open("example.txt","r") as file:
    data=file.read
    print(data)
# Out:
# <built-in method read of _io.TextIOWrapper object at 0x000001906B3F4C80>

# %%
os.remove("example.txt")
print("file deleted")
# Out:
# file deleted

# %%
# Input= Data given to the program.
# Output= Result produce by program.

# Input-->Processing-->Output-->Program.

# %%
name=input("Enter your name")
print("My name is: ",name)
# Out:
# Enter your name Chandan
# My name is:  Chandan

# %%
age=int(input("Enter your age"))
print(age+5)
# Out:
# Enter your age 43
# 48

# %%
name="python"
version="3.13.7"
print(name,version)
# Out:
# python 3.13.7

# %%
name="python"
version="3.13.7"
print("Name:{},version:{}".format(name,version))
# Out:
# Name:python,version:3.13.7

# %%
# Take two input at a same time ,using space for differ the values. like 5 6 =11.
a,b=map(int,input("Enter two numbers:").split())  
print(a+b)
# Out:
# Enter two numbers: 5 5
# 10

# %%
print("Hello","World",sep="-",end="!")
# Out:
# Hello-World!

# %%
# import can be done by three ways:
# 1. import math:
#     math.sqrt(25)
# 2. import specific function:
#    from math import sqrt,pow
#     sqrt(25)
# 3. import using alias np
#    import numpy as np

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
 import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\asus\Desktop\Datasets\mlops_dataset.csv")
df
# Out:
#    experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 0       exp_0001  2023-08-17            XGBoost     ImageNet              3.0
# 1       exp_0002  2023-02-21                SVM     ImageNet              1.0
# 2       exp_0003  2024-07-17        Transformer         IMDB              2.0
# 3       exp_0004  2024-05-16            XGBoost         SVHN              2.0
# 4       exp_0005  2024-04-02            XGBoost      CIFAR10              2.0
# ..           ...         ...                ...          ...              ...
# 95      exp_0096  2023-04-07                SVM       Custom              3.0
# 96      exp_0097  2023-08-13                SVM      CIFAR10              2.0
# 97      exp_0098  2023-11-10            XGBoost     ImageNet              2.0
# 98      exp_0099  2023-11-24        Transformer     ImageNet              2.0
# 99      exp_0100  2025-05-14       RandomForest      CIFAR10              2.1
#
# ...

# %%
df.shape
# Out:
# (100, 16)

# %%
df.head()
# Out:
#   experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 0      exp_0001  2023-08-17            XGBoost     ImageNet              3.0
# 1      exp_0002  2023-02-21                SVM     ImageNet              1.0
# 2      exp_0003  2024-07-17        Transformer         IMDB              2.0
# 3      exp_0004  2024-05-16            XGBoost         SVHN              2.0
# 4      exp_0005  2024-04-02            XGBoost      CIFAR10              2.0
#
#    learning_rate  batch_size  epochs  accuracy  precision  recall  f1_score  \
# 0        0.00031         128      81    0.9659     0.9891  0.9758    0.9824
# 1        0.00004         256      39    0.5764     0.5322  0.6130    0.5697
# 2        0.00254         128       5    0.8470     0.7991  0.8940    0.8439
# 3        0.02137         256      18    0.6040     0.5722  0.5723    0.5722
# 4        0.00016          64      25    0.7571     0.7503  0.7362    0.7432
#
# ...

# %%
df.head(8)
# Out:
#   experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 0      exp_0001  2023-08-17            XGBoost     ImageNet              3.0
# 1      exp_0002  2023-02-21                SVM     ImageNet              1.0
# 2      exp_0003  2024-07-17        Transformer         IMDB              2.0
# 3      exp_0004  2024-05-16            XGBoost         SVHN              2.0
# 4      exp_0005  2024-04-02            XGBoost      CIFAR10              2.0
# 5      exp_0006  2023-10-13        Transformer         IMDB              1.0
# 6      exp_0007  2023-07-29             ResNet       Custom              1.0
# 7      exp_0008  2023-06-28             ResNet         COCO              3.0
#
#    learning_rate  batch_size  epochs  accuracy  precision  recall  f1_score  \
# 0        0.00031         128      81    0.9659     0.9891  0.9758    0.9824
# 1        0.00004         256      39    0.5764     0.5322  0.6130    0.5697
# ...

# %%
df.tail()
# Out:
#    experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 95      exp_0096  2023-04-07                SVM       Custom              3.0
# 96      exp_0097  2023-08-13                SVM      CIFAR10              2.0
# 97      exp_0098  2023-11-10            XGBoost     ImageNet              2.0
# 98      exp_0099  2023-11-24        Transformer     ImageNet              2.0
# 99      exp_0100  2025-05-14       RandomForest      CIFAR10              2.1
#
#     learning_rate  batch_size  epochs  accuracy  precision  recall  f1_score  \
# 95        0.00003          64      77    0.8414     0.8543  0.8791    0.8665
# 96        0.00872          64      89    0.8937     0.8719  0.8614    0.8666
# 97        0.01006          16      57    0.8953     0.9444  0.8866    0.9146
# 98        0.00031          64      95    0.8804     0.8645  0.9235    0.8930
# 99        0.02714         256      89    0.7102     0.7353  0.7357    0.7355
#
# ...

# %%
df.tail(8)
# Out:
#    experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 92      exp_0093  2025-11-09                SVM         IMDB              1.0
# 93      exp_0094  2025-10-07             ResNet      CIFAR10              4.2
# 94      exp_0095  2023-07-06            XGBoost       Custom              4.2
# 95      exp_0096  2023-04-07                SVM       Custom              3.0
# 96      exp_0097  2023-08-13                SVM      CIFAR10              2.0
# 97      exp_0098  2023-11-10            XGBoost     ImageNet              2.0
# 98      exp_0099  2023-11-24        Transformer     ImageNet              2.0
# 99      exp_0100  2025-05-14       RandomForest      CIFAR10              2.1
#
#     learning_rate  batch_size  epochs  accuracy  precision  recall  f1_score  \
# 92        0.00006          16      56    0.5340     0.4941  0.4858    0.4899
# 93        0.00002          64      15    0.8347     0.7918  0.8166    0.8040
# ...

# %%
df.T
# Out:
#                                          0                      1   \
# experiment_id                      exp_0001               exp_0002
# run_date                         2023-08-17             2023-02-21
# model_architecture                  XGBoost                    SVM
# dataset_name                       ImageNet               ImageNet
# dataset_version                         3.0                    1.0
# learning_rate                       0.00031                0.00004
# batch_size                              128                    256
# epochs                                   81                     39
# accuracy                             0.9659                 0.5764
# precision                            0.9891                 0.5322
# recall                               0.9758                  0.613
# f1_score                             0.9824                 0.5697
# training_time_minutes                   968                   1584
# ...

# %%
df.drop(1)
# Out:
#    experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 0       exp_0001  2023-08-17            XGBoost     ImageNet              3.0
# 2       exp_0003  2024-07-17        Transformer         IMDB              2.0
# 3       exp_0004  2024-05-16            XGBoost         SVHN              2.0
# 4       exp_0005  2024-04-02            XGBoost      CIFAR10              2.0
# 5       exp_0006  2023-10-13        Transformer         IMDB              1.0
# ..           ...         ...                ...          ...              ...
# 95      exp_0096  2023-04-07                SVM       Custom              3.0
# 96      exp_0097  2023-08-13                SVM      CIFAR10              2.0
# 97      exp_0098  2023-11-10            XGBoost     ImageNet              2.0
# 98      exp_0099  2023-11-24        Transformer     ImageNet              2.0
# 99      exp_0100  2025-05-14       RandomForest      CIFAR10              2.1
#
# ...

# %%
df
# Out:
#    experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 0       exp_0001  2023-08-17            XGBoost     ImageNet              3.0
# 1       exp_0002  2023-02-21                SVM     ImageNet              1.0
# 2       exp_0003  2024-07-17        Transformer         IMDB              2.0
# 3       exp_0004  2024-05-16            XGBoost         SVHN              2.0
# 4       exp_0005  2024-04-02            XGBoost      CIFAR10              2.0
# ..           ...         ...                ...          ...              ...
# 95      exp_0096  2023-04-07                SVM       Custom              3.0
# 96      exp_0097  2023-08-13                SVM      CIFAR10              2.0
# 97      exp_0098  2023-11-10            XGBoost     ImageNet              2.0
# 98      exp_0099  2023-11-24        Transformer     ImageNet              2.0
# 99      exp_0100  2025-05-14       RandomForest      CIFAR10              2.1
#
# ...

# %%
df.drop(1,inplace=True)
df
# Out:
#    experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 0       exp_0001  2023-08-17            XGBoost     ImageNet              3.0
# 2       exp_0003  2024-07-17        Transformer         IMDB              2.0
# 3       exp_0004  2024-05-16            XGBoost         SVHN              2.0
# 4       exp_0005  2024-04-02            XGBoost      CIFAR10              2.0
# 5       exp_0006  2023-10-13        Transformer         IMDB              1.0
# ..           ...         ...                ...          ...              ...
# 95      exp_0096  2023-04-07                SVM       Custom              3.0
# 96      exp_0097  2023-08-13                SVM      CIFAR10              2.0
# 97      exp_0098  2023-11-10            XGBoost     ImageNet              2.0
# 98      exp_0099  2023-11-24        Transformer     ImageNet              2.0
# 99      exp_0100  2025-05-14       RandomForest      CIFAR10              2.1
#
# ...

# %%
df["Rank"]=df["batch_size"].rank()

# %%
df
# Out:
#    experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 0       exp_0001  2023-08-17            XGBoost     ImageNet              3.0
# 2       exp_0003  2024-07-17        Transformer         IMDB              2.0
# 3       exp_0004  2024-05-16            XGBoost         SVHN              2.0
# 4       exp_0005  2024-04-02            XGBoost      CIFAR10              2.0
# 5       exp_0006  2023-10-13        Transformer         IMDB              1.0
# ..           ...         ...                ...          ...              ...
# 95      exp_0096  2023-04-07                SVM       Custom              3.0
# 96      exp_0097  2023-08-13                SVM      CIFAR10              2.0
# 97      exp_0098  2023-11-10            XGBoost     ImageNet              2.0
# 98      exp_0099  2023-11-24        Transformer     ImageNet              2.0
# 99      exp_0100  2025-05-14       RandomForest      CIFAR10              2.1
#
# ...

# %%
df["Rank"]=df["batch_size"].rank(ascending=False).astype("int")

# %%
df
# Out:
#    experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 0       exp_0001  2023-08-17            XGBoost     ImageNet              3.0
# 2       exp_0003  2024-07-17        Transformer         IMDB              2.0
# 3       exp_0004  2024-05-16            XGBoost         SVHN              2.0
# 4       exp_0005  2024-04-02            XGBoost      CIFAR10              2.0
# 5       exp_0006  2023-10-13        Transformer         IMDB              1.0
# ..           ...         ...                ...          ...              ...
# 95      exp_0096  2023-04-07                SVM       Custom              3.0
# 96      exp_0097  2023-08-13                SVM      CIFAR10              2.0
# 97      exp_0098  2023-11-10            XGBoost     ImageNet              2.0
# 98      exp_0099  2023-11-24        Transformer     ImageNet              2.0
# 99      exp_0100  2025-05-14       RandomForest      CIFAR10              2.1
#
# ...

# %%
df.sort_values("batch_size",ascending=False)
# Out:
#    experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 99      exp_0100  2025-05-14       RandomForest      CIFAR10              2.1
# 12      exp_0013  2024-03-23             ResNet       Custom              2.0
# 33      exp_0034  2025-01-05                CNN         COCO              2.0
# 46      exp_0047  2024-04-11               LSTM         COCO              2.1
# 47      exp_0048  2024-08-15       RandomForest         COCO              2.0
# ..           ...         ...                ...          ...              ...
# 62      exp_0063  2024-05-16               LSTM         SVHN              4.2
# 20      exp_0021  2024-07-23            XGBoost         COCO              4.2
# 55      exp_0056  2023-11-30                CNN       Custom              2.0
# 23      exp_0024  2025-05-15            XGBoost     ImageNet              4.2
# 31      exp_0032  2025-02-17                SVM        MNIST              1.0
#
# ...

# %%
df["DensRank"]=df["batch_size"].rank(method="dense",ascending=False).astype("int")

# %%
df
# Out:
#    experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 0       exp_0001  2023-08-17            XGBoost     ImageNet              3.0
# 2       exp_0003  2024-07-17        Transformer         IMDB              2.0
# 3       exp_0004  2024-05-16            XGBoost         SVHN              2.0
# 4       exp_0005  2024-04-02            XGBoost      CIFAR10              2.0
# 5       exp_0006  2023-10-13        Transformer         IMDB              1.0
# ..           ...         ...                ...          ...              ...
# 95      exp_0096  2023-04-07                SVM       Custom              3.0
# 96      exp_0097  2023-08-13                SVM      CIFAR10              2.0
# 97      exp_0098  2023-11-10            XGBoost     ImageNet              2.0
# 98      exp_0099  2023-11-24        Transformer     ImageNet              2.0
# 99      exp_0100  2025-05-14       RandomForest      CIFAR10              2.1
#
# ...

# %%
df.sort_values("batch_size",ascending=False)
# Out:
#    experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 99      exp_0100  2025-05-14       RandomForest      CIFAR10              2.1
# 12      exp_0013  2024-03-23             ResNet       Custom              2.0
# 33      exp_0034  2025-01-05                CNN         COCO              2.0
# 46      exp_0047  2024-04-11               LSTM         COCO              2.1
# 47      exp_0048  2024-08-15       RandomForest         COCO              2.0
# ..           ...         ...                ...          ...              ...
# 62      exp_0063  2024-05-16               LSTM         SVHN              4.2
# 20      exp_0021  2024-07-23            XGBoost         COCO              4.2
# 55      exp_0056  2023-11-30                CNN       Custom              2.0
# 23      exp_0024  2025-05-15            XGBoost     ImageNet              4.2
# 31      exp_0032  2025-02-17                SVM        MNIST              1.0
#
# ...

# %%
df[df["model_architecture"].isin(['RandomForest','CNN'])]
# Out:
#    experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 14      exp_0015  2025-10-31       RandomForest         COCO              1.0
# 22      exp_0023  2023-11-23                CNN       Custom              1.0
# 28      exp_0029  2024-11-20                CNN         COCO              4.2
# 29      exp_0030  2023-07-29                CNN         COCO              4.2
# 33      exp_0034  2025-01-05                CNN         COCO              2.0
# 35      exp_0036  2024-06-25       RandomForest      CIFAR10              1.0
# 44      exp_0045  2023-05-23       RandomForest         COCO              2.0
# 47      exp_0048  2024-08-15       RandomForest         COCO              2.0
# 53      exp_0054  2025-07-17       RandomForest         COCO              3.0
# 55      exp_0056  2023-11-30                CNN       Custom              2.0
# 59      exp_0060  2024-06-30                CNN         COCO              2.1
# ...

# %%
df[~df['DensRank'].isin(['1','2','3','18','78','90'])]
# Out:
#    experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 0       exp_0001  2023-08-17            XGBoost     ImageNet              3.0
# 2       exp_0003  2024-07-17        Transformer         IMDB              2.0
# 3       exp_0004  2024-05-16            XGBoost         SVHN              2.0
# 4       exp_0005  2024-04-02            XGBoost      CIFAR10              2.0
# 5       exp_0006  2023-10-13        Transformer         IMDB              1.0
# ..           ...         ...                ...          ...              ...
# 95      exp_0096  2023-04-07                SVM       Custom              3.0
# 96      exp_0097  2023-08-13                SVM      CIFAR10              2.0
# 97      exp_0098  2023-11-10            XGBoost     ImageNet              2.0
# 98      exp_0099  2023-11-24        Transformer     ImageNet              2.0
# 99      exp_0100  2025-05-14       RandomForest      CIFAR10              2.1
#
# ...

# %%
df2=pd.read_excel(r"C:\Users\asus\Desktop\Datasets\Task 1 Voting Team Contact List.xlsx")
df2
# Out:
#    Accenture Online Voting Pilot for Australian Federal Government - Team Contact List  \
# 0                                                 NaN
# 1   Collaboration Zone Link: AUSOnlineVoting/ACCSl...
# 2                                               Name
# 3                                         Susan Smith
# 4                                     Reginald Height
# 5                                           Lisa Chen
# 6                                         Sandeep Rao
# 7                                       Phil Kurinsky
# 8                                                 NaN
# 9                                                 NaN
# 10                                                ***
# 11                                                NaN
#
#                                            Unnamed: 1       Unnamed: 2  \
# 0                                                 NaN              NaN
# 1                                                 NaN              NaN
# ...

# %%
df.iloc[0:5]
# Out:
#   experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 0      exp_0001  2023-08-17            XGBoost     ImageNet              3.0
# 1      exp_0002  2023-02-21                SVM     ImageNet              1.0
# 2      exp_0003  2024-07-17        Transformer         IMDB              2.0
# 3      exp_0004  2024-05-16            XGBoost         SVHN              2.0
# 4      exp_0005  2024-04-02            XGBoost      CIFAR10              2.0
#
#    learning_rate  batch_size  epochs  accuracy  precision  recall  f1_score  \
# 0        0.00031         128      81    0.9659     0.9891  0.9758    0.9824
# 1        0.00004         256      39    0.5764     0.5322  0.6130    0.5697
# 2        0.00254         128       5    0.8470     0.7991  0.8940    0.8439
# 3        0.02137         256      18    0.6040     0.5722  0.5723    0.5722
# 4        0.00016          64      25    0.7571     0.7503  0.7362    0.7432
#
# ...

# %%
df.iloc[0:5,1:5]  #for row and colunm both
# Out:
#      run_date model_architecture dataset_name  dataset_version
# 0  2023-08-17            XGBoost     ImageNet              3.0
# 1  2023-02-21                SVM     ImageNet              1.0
# 2  2024-07-17        Transformer         IMDB              2.0
# 3  2024-05-16            XGBoost         SVHN              2.0
# 4  2024-04-02            XGBoost      CIFAR10              2.0

# %%
df.iloc[[1,5,7,8],[2,3]]
# Out:
#   model_architecture dataset_name
# 1                SVM     ImageNet
# 5        Transformer         IMDB
# 7             ResNet         COCO
# 8             ResNet       Custom

# %%
p=df.set_index("dataset_name")

# %%
p
# Out:
#              experiment_id    run_date model_architecture  dataset_version  \
# dataset_name
# ImageNet          exp_0001  2023-08-17            XGBoost              3.0
# ImageNet          exp_0002  2023-02-21                SVM              1.0
# IMDB              exp_0003  2024-07-17        Transformer              2.0
# SVHN              exp_0004  2024-05-16            XGBoost              2.0
# CIFAR10           exp_0005  2024-04-02            XGBoost              2.0
# ...                    ...         ...                ...              ...
# Custom            exp_0096  2023-04-07                SVM              3.0
# CIFAR10           exp_0097  2023-08-13                SVM              2.0
# ImageNet          exp_0098  2023-11-10            XGBoost              2.0
# ImageNet          exp_0099  2023-11-24        Transformer              2.0
# CIFAR10           exp_0100  2025-05-14       RandomForest              2.1
#
# ...

# %%
df['model_architecture']=df['model_architecture'].str.upper()

# %%
df
# Out:
#    experiment_id    run_date model_architecture dataset_name  dataset_version  \
# 0       exp_0001  2023-08-17            XGBOOST     ImageNet              3.0
# 1       exp_0002  2023-02-21                SVM     ImageNet              1.0
# 2       exp_0003  2024-07-17        TRANSFORMER         IMDB              2.0
# 3       exp_0004  2024-05-16            XGBOOST         SVHN              2.0
# 4       exp_0005  2024-04-02            XGBOOST      CIFAR10              2.0
# ..           ...         ...                ...          ...              ...
# 95      exp_0096  2023-04-07                SVM       Custom              3.0
# 96      exp_0097  2023-08-13                SVM      CIFAR10              2.0
# 97      exp_0098  2023-11-10            XGBOOST     ImageNet              2.0
# 98      exp_0099  2023-11-24        TRANSFORMER     ImageNet              2.0
# 99      exp_0100  2025-05-14       RANDOMFOREST      CIFAR10              2.1
#
# ...

# %%
 # '''map() will work on table columns
 # apply()
 # applymap()'''

# %%
df2=pd.read_excel(r"C:\Users\asus\Desktop\Datasets\small 20 row data.xlsx")
df2
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
'''Seaborn: 
Seaborn ek Python data visualization library hai 📊
Jo Matplotlib ke upar built hoti hai aur statistical graphs banana ka kaam easy aur attractive bana deti hai.

Thoda simple bolun to 👇
👉 Seaborn = data ko samajhne ke liye smart + beautiful charts

Seaborn kya karta hai?

1.DataFrame (pandas) ke saath direct kaam karta hai
2.Default charts hi kaafi achhe dikhte hain
3.Statistical plots banana super easy ho jata hai

Common Seaborn plots
1.sns.lineplot() – trend dekhne ke liye
2.sns.barplot() – category vs value
3.sns.countplot() – count nikalne ke liye
4.sns.histplot() – distribution
5.sns.boxplot() – outliers + spread
6.sns.heatmap() – correlation / matrix
7.sns.pairplot() – poora dataset ek saath'''
# Out:
# 'Seaborn: \nSeaborn ek Python data visualization library hai 📊\nJo Matplotlib ke upar built hoti hai aur statistical graphs banana ka kaam easy aur attractive bana deti hai.\n\nThoda simple bolun to 👇\n👉 Seaborn = data ko samajhne ke liye smart + beautiful charts\n\nSeaborn kya karta hai?\n\n1.DataFrame (pandas) ke saath direct kaam karta hai\n2.Default charts hi kaafi achhe dikhte hain\n3.Statistical plots banana super easy ho jata hai\n\nCommon Seaborn plots\n1.sns.lineplot() – trend dekhne ke liye\n2.sns.barplot() – category vs value\n3.sns.countplot() – count nikalne ke liye\n4.sns.histplot() – distribution\n5.sns.boxplot() – outliers + spread\n6.sns.heatmap() – correlation / matrix\n7.sns.pairplot() – poora dataset ek saath'

# %%
import pandas as pd
df2= {'Team':['Riders','Riders','Devils','Devils','Kings','Kings','Kings','Kings','Riders','Royals','Royals','Royals','Rcb'],
            'Rank':[1,2,2,3,3,4,1,1,2,4,1,2,1],
            'Year':[2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017,2018],
            'Points':[876,789,863,673,741,812,756,788,694,701,884,690,918],
            
           }
df=pd.DataFrame(df2)
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     884
# 11  Royals     2  2017     690
# 12     Rcb     1  2018     918

# %%
df["Team"].value_counts()
# Out:
# Team
# Kings     4
# Riders    3
# Royals    3
# Devils    2
# Rcb       1
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(x="Team",hue="Year",data=df)
# Out:
# <Axes: xlabel='Team', ylabel='count'>

# %%
sns.pairplot(df)

# %%
sns.get_dataset_names()      # these are pre define dataset in seaborn.
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
s=sns.load_dataset('tips')
s
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x='total_bill',y='tip',data=s)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',data=s)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x='total_bill',y='tip',hue='sex',data=s)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import matplotlib.pyplot as plt

# %%
# col= day can make the graph according to day.
sns.relplot(x='total_bill',y='tip',hue='sex',col='day',data=s)
plt.show()

# %%
# col=time make graph according to time.
sns.relplot(x='total_bill',y='tip',hue='sex',col='time',data=s)
plt.show()

# %%
t=sns.load_dataset('iris')
t
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(data=t)
plt.show()

# %%
sns.pairplot(data=t,hue='species')
plt.show()

# %%
s
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
s['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
r=s[["sex","smoker"]].value_counts()
r
# Out:
# sex     smoker
# Male    No        97
#         Yes       60
# Female  No        54
#         Yes       33
# Name: count, dtype: int64

# %%
# s.groupby(["sex","smoker"]).value_counts()

# %%
r.plot.bar()
# Out:
# <Axes: xlabel='sex,smoker'>

# %%
s[s['sex']=='Male']
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
v=sns.load_dataset('flights')
v
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
t=v.groupby('year')['passengers'].sum()
t
# Out:
# year
# 1949    1520
# 1950    1676
# 1951    2042
# 1952    2364
# 1953    2700
# 1954    2867
# 1955    3408
# 1956    3939
# 1957    4421
# 1958    4572
# 1959    5140
# 1960    5714
# Name: passengers, dtype: int64

# %%
t.plot()
# Out:
# <Axes: xlabel='year'>

# %%
t1=v.groupby('month')['passengers'].sum()
t1
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_12832\3745308372.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   t1=v.groupby('month')['passengers'].sum()
# month
# Jan    2901
# Feb    2820
# Mar    3242
# Apr    3205
# May    3262
# Jun    3740
# Jul    4216
# Aug    4213
# Sep    3629
# Oct    3199
# Nov    2794
# Dec    3142
# Name: passengers, dtype: int64

# %%
t1.plot()
# Out:
# <Axes: xlabel='month'>

# %%
t=v.groupby(['year','month'])['passengers'].sum()
t
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_12832\866460170.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   t=v.groupby(['year','month'])['passengers'].sum()
# year  month
# 1949  Jan      112
#       Feb      118
#       Mar      132
#       Apr      129
#       May      121
#               ...
# 1960  Aug      606
#       Sep      508
#       Oct      461
#       Nov      390
#       Dec      432
# Name: passengers, Length: 144, dtype: int64

# %%
t.plot.bar(label='month')
# Out:
# <Axes: xlabel='year,month'>

# %%
sns.barplot(x="year",y="passengers",hue="month",data=v)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

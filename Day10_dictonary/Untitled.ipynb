# %%
# Dictionary:
# A Python dictionary (dict) is a built-in, mutable data structure that stores data in key-value pairs.
    # It is highly efficient for data retrieval using unique keys, functioning like a hash table
# dic is denoted by {}
# dic store the data on key
# dic is a mulatble
# dic key can't be dublicate and null
# key can be any data type.
# dic is also called JSON data.
# dic is a collection of object type element.
# dic is a class of collecrion.
# dic can store the data based on keys.

# %%
d={234:'raj',111:'monu',900:'arjun',500:'harsh',777:'harsh'}
d
d[111]
# Out:
# 'monu'

# %%
d.pop(500)                    # pop for delete
d
# Out:
# {234: 'raj', 111: 'monu', 900: 'arjun', 777: 'harsh'}

# %%
d.clear()
d
# Out:
# {}

# %%
d={234:'raj',111:'monu',900:'arjun',500:'harsh',777:'harsh'}
d.popitem()  # dic pop without work with perameter.
d            # popitem is used for delete last item in dic.
# Out:
# {234: 'raj', 111: 'monu', 900: 'arjun', 500: 'harsh'}

# %%
d={234:'raj',111:'monu',900:'arjun',500:'harsh',777:'harsh'}
d.setdefault(766,'chandan')           # is used for add element at last position of index.
d
# Out:
# {234: 'raj',
#  111: 'monu',
#  900: 'arjun',
#  500: 'harsh',
#  777: 'harsh',
#  766: 'chandan'}

# %%
# user definr dictionary.
x=int(input('Eneter the size of dic'))
d={}
for i in range(0,x):
    k=eval(input("Enter the key"))
    v=eval(input("Eneter the value"))
    d.setdefault(k,v)
d
# Out:
# Eneter the size of dic 5
# Enter the key 23
# Eneter the value 55
# Enter the key 34
# Eneter the value 'chandan'
# Enter the key 66
# Eneter the value 'aadil'
# Enter the key 67
# Eneter the value 'deepak'
# Enter the key 55
# Eneter the value 99
# {23: 55, 34: 'chandan', 66: 'aadil', 67: 'deepak', 55: 99}

# %%
d={'id':3456,'name':'chandan','age':21,'contact':9312436787}
print(d.keys())     # to find the all keys of dictionary.
print(d.values())    # to fing the all values of dict.
print(d.items())         # to find the all keys and values
len(d.items())          # to print the length
# Out:
# dict_keys(['id', 'name', 'age', 'contact'])
# dict_values([3456, 'chandan', 21, 9312436787])
# dict_items([('id', 3456), ('name', 'chandan'), ('age', 21), ('contact', 9312436787)])
# 4

# %%
d={'id':3456,'name':'chandan','age':21,'contact':9312436787}
for i in d.items():
    print(i)
for i,j in d.items():
    print(i,"-",j)
# Out:
# ('id', 3456)
# ('name', 'chandan')
# ('age', 21)
# ('contact', 9312436787)
# id - 3456
# name - chandan
# age - 21
# contact - 9312436787

# %%
student = {"name": "Chandan", "age": 21, "course": "BCA"}

student.pop("age")
del student["course"]

print(student)
# Out:
# {'name': 'Chandan'}

# %%
student = {"name": "Chandan", "age": 21, "course": "BCA"}

student.pop("age")                    # to delete the element using keys.
del student["course"]

print(student.get('name'))            # to get the element using keys.
# Out:
# Chandan

# %%
d={234:'raj',111:'monu',900:'arjun',500:'harsh',777:'harsh'}
for i in sorted(d.items()):
    print(i)
# Out:
# (111, 'monu')
# (234, 'raj')
# (500, 'harsh')
# (777, 'harsh')
# (900, 'arjun')

# %%
d={234:'raj',111:'monu',900:'arjun',500:'harsh',777:'harsh'}
for i in reversed(sorted(d.items())):
    print(i)
# Out:
# (900, 'arjun')
# (777, 'harsh')
# (500, 'harsh')
# (234, 'raj')
# (111, 'monu')

# %%
d={234:'raj',111:'monu',900:'arjun',500:'harsh',777:'harsh'}
d[900]='chandan'
print(d)
# Out:
# {234: 'raj', 111: 'monu', 900: 'chandan', 500: 'harsh', 777: 'harsh'}

# %%
d={234:'raj',111:'monu',900:'arjun',500:'harsh',777:'harsh'}
d2= {"name": "Chandan", "age": 21, "course": "BCA"}
d.update(d2)
print(d)
# Out:
# {234: 'raj', 111: 'monu', 900: 'arjun', 500: 'harsh', 777: 'harsh', 'name': 'Chandan', 'age': 21, 'course': 'BCA'}

# %%
d2= {"name":["Chandan","Akash","Badal"], "age": [21,22,23], "course": ["BCA","Btech","BBA"]}
print(d2)
# Out:
# {'name': ['Chandan', 'Akash', 'Badal'], 'age': [21, 22, 23], 'course': ['BCA', 'Btech', 'BBA']}

# %%
import pandas as pd
d2= {"name":["Chandan","Akash","Badal"], "age": [21,22,23], "course": ["BCA","Btech","BBA"]}
df=pd.DataFrame(d2)
print(df)
# Out:
#       name  age course
# 0  Chandan   21    BCA
# 1    Akash   22  Btech
# 2    Badal   23    BBA

# %%
import pandas as pd
d2= {"name":["Chandan","Akash","Badal"], "age": [21,22,23], "course": ["BCA","Btech","BBA"]}
df=pd.DataFrame(d2)
df.to_csv(r"C:/Users/asus/Documents/data3.csv")

# %%
d={'a':1,'b':2}
d2={'a':1,'b':2}
d3={'a':1,'c':2}
d4={'a':1,'b':3}
print(d==d2)
print(d==d3)
print(d==d4)
# Out:
# True
# False
# False

# %%
# Convert list into dictionary.
k=['id','name','age','address']
k2=[123,'Chandan',21,'Ghaziabad']
d=dict(zip(k,k2))             # zip method is used for create dict using two list.
d
# Out:
# {'id': 123, 'name': 'Chandan', 'age': 21, 'address': 'Ghaziabad'}

# %%
# Dictionary comprehension :
# Dictionary comprehension is a method for transforming one dictionary into another dictionary. 
# During this transformation, items within the original dictionary can be conditionally included in the new dictionary
# and each item can be transformed as needed.

# %%
d={i:i**2 for i in range(1,11)}
d
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
# Remove dict key space with dict comprehensionn.
d={'first name':'chandan','last name':'Thakur','age':21}
s={k.replace(' ',''):v for k,v in d.items()}
s
# Out:
# {'firstname': 'chandan', 'lastname': 'Thakur', 'age': 21}

# %%
# Count repeat 
s= "Dictionary comprehension is a method for transforming one dictionary into another Dictionary"
t=s.split()
# print(t)

d={i:t.count(i) for i in t}
print(d)
# Out:
# {'Dictionary': 2, 'comprehension': 1, 'is': 1, 'a': 1, 'method': 1, 'for': 1, 'transforming': 1, 'one': 1, 'dictionary': 1, 'into': 1, 'another': 1}

# %%
# Find the maximum key values in python using dict comprehension.
d={'hr':45,'it':65,'cs':55,'sales':50}
temp=max(d.values())
print(temp)

results={i for i in d if d[i]==temp}
results
# Out:
# 65
# {'it'}

# %%
d={'hr':45,'it':65,'cs':55,'sales':50}
del d['it']
d
# Out:
# {'hr': 45, 'cs': 55, 'sales': 50}

# %%
# Nested Dictionary.
# A nested dictionary is a dictionary that contains another dictionary as a value.
# It helps organize complex or grouped data, like student details or product info in a clean and structured way.

# %%
# Creating a Nested Dictionary
Dict = { 1: 'Geeks', 
         2: 'For', 
         3: {'A': 'Welcome', 'B': 'To', 'C': 'Geeks'} }
Dict
# Out:
# {1: 'Geeks', 2: 'For', 3: {'A': 'Welcome', 'B': 'To', 'C': 'Geeks'}}

# %%
dic={1:{'name':'raj','id':123,'age':23},2:{'name':'raju','id':121,'age':22}}
print(dic[1]['id'])
print(dic[2]['age'])
# Out:
# 123
# 22

# %%
dic={1:{'name':'raj','id':123,'age':23},2:{'name':'raju','id':121,'age':22}}
dic[1]['id']=122
dic[2]['age']=45
dic
# Out:
# {1: {'name': 'raj', 'id': 122, 'age': 23},
#  2: {'name': 'raju', 'id': 121, 'age': 45}}
